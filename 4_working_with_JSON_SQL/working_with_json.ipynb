# %% [markdown]
# # Working with JSON & SQL using Pandas
#
# In this notebook, we will explore how to work with **JSON data** and connect to **MySQL databases** using Pandas. These skills are crucial when dealing with real-world data stored in files, APIs, or relational databases.
#
# ---
#
# ## Working with JSON Data
#
# Pandas provides an easy way to read JSON files using `pd.read_json()`.
#
# ### Reading Local JSON File

# %%
import pandas as pd

# %%
pd.read_json('train.json') # # Reading a local JSON file
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# This assumes the file `train.json` exists in the current directory. The structure of the file should be either a JSON array or a line-delimited format depending on your use case.

# %% [markdown]
# ### Reading JSON from a Web API
# Let’s try an open JSON API:

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/NPR').head()
# Out:
#                              provider  \
# NPR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# NPR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# NPR  https://www.exchangerate-api.com/terms  NPR 2025-07-05
# AED  https://www.exchangerate-api.com/terms  NPR 2025-07-05
# AFN  https://www.exchangerate-api.com/terms  NPR 2025-07-05
# ALL  https://www.exchangerate-api.com/terms  NPR 2025-07-05
# AMD  https://www.exchangerate-api.com/terms  NPR 2025-07-05
#
#      time_last_updated   rates
# NPR         1751673602  1.0000
# AED         1751673602  0.0268
# AFN         1751673602  0.5110
# ALL         1751673602  0.6070
# AMD         1751673602  2.8100

# %% [markdown]
# This API returns the latest currency exchange rates with NPR as the base. The full response contains nested structures like `rates`, `date`, and `base`.

# %% [markdown]
# ### Working with SQL Databases
# #### Step 1: Installing MySQL Connector
# We use the official MySQL connector to connect Python with MySQL.

# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.3.0-cp310-cp310-win_amd64.whl.metadata (7.5 kB)
# Downloading mysql_connector_python-9.3.0-cp310-cp310-win_amd64.whl (16.4 MB)
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.4 MB 885.6 kB/s eta 0:00:18
#    -- ------------------------------------- 1.0/16.4 MB 1.4 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.1/16.4 MB 2.3 MB/s eta 0:00:07
#    -------- ------------------------------- 3.7/16.4 MB 3.4 MB/s eta 0:00:04
#    ------------ --------------------------- 5.0/16.4 MB 4.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.6/16.4 MB 4.5 MB/s eta 0:00:03
#    --------------------- ------------------ 8.9/16.4 MB 5.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.8/16.4 MB 6.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.4 MB 7.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.4 MB 7.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.4 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.9/16.4 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------- -- 15.2/16.4 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 15.2/16.4 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 15.5/16.4 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------- -- 15.5/16.4 MB 4.8 MB/s eta 0:00:01
#    -------------------------------------- - 15.7/16.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.4 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.4 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 3.8 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.3.0

# %% [markdown]
# ### Step 2: Connecting to a MySQL Database

# %%
import mysql.connector

# Create a connection to MySQL with the required credentials
con = mysql.connector.connect(
    host='localhost', 
    user='root', 
    password='', 
    database='world'
)

# %% [markdown]
# ### Step 3: Run SQL Queries using Pandas

# %%
pd.read_sql_query("SELECT * FROM country WHERE Continent='Oceania'", conn).head()
# Out:
#   Code                     Name Continent                     Region  \
# 0  ASM           American Samoa   Oceania                  Polynesia
# 1  AUS                Australia   Oceania  Australia and New Zealand
# 2  CCK  Cocos (Keeling) Islands   Oceania  Australia and New Zealand
# 3  COK             Cook Islands   Oceania                  Polynesia
# 4  CXR         Christmas Island   Oceania  Australia and New Zealand
#
#    SurfaceArea  IndepYear  Population  LifeExpectancy       GNP    GNPOld  \
# 0        199.0        NaN       68000            75.1     334.0       NaN
# 1    7741220.0     1901.0    18886000            79.8  351182.0  392911.0
# 2         14.0        NaN         600             NaN       0.0       NaN
# 3        236.0        NaN       20000            71.1     100.0       NaN
# 4        135.0        NaN        2500             NaN       0.0       NaN
#
#                  LocalName                            GovernmentForm  \
# 0            Amerika Samoa                              US Territory
# 1                Australia       Constitutional Monarchy, Federation
# 2  Cocos (Keeling) Islands                    Territory of Australia
# 3         The Cook Islands  Nonmetropolitan Territory of New Zealand
# 4         Christmas Island                    Territory of Australia
#
#       HeadOfState  Capital Code2
# 0  George W. Bush     54.0    AS
# 1    Elisabeth II    135.0    AU
# 2    Elisabeth II   2317.0    CC
# 3    Elisabeth II    583.0    CK
# 4    Elisabeth II   1791.0    CX

# %% [markdown]
# ### Handling Pandas SQL Warning
#
# When you use a raw DB-API connection (like from mysql.connector), Pandas shows this warning:
#
# **"pandas only supports SQLAlchemy connectable..."**
#
# We have two options to deal with this.

# %% [markdown]
# #### Option 1: Suppress the Warning (For Learning)

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

pd.read_sql_query("SELECT * FROM country WHERE Continent='Oceania'", con).head()
# Out:
#   Code                     Name Continent                     Region  \
# 0  ASM           American Samoa   Oceania                  Polynesia
# 1  AUS                Australia   Oceania  Australia and New Zealand
# 2  CCK  Cocos (Keeling) Islands   Oceania  Australia and New Zealand
# 3  COK             Cook Islands   Oceania                  Polynesia
# 4  CXR         Christmas Island   Oceania  Australia and New Zealand
#
#    SurfaceArea  IndepYear  Population  LifeExpectancy       GNP    GNPOld  \
# 0        199.0        NaN       68000            75.1     334.0       NaN
# 1    7741220.0     1901.0    18886000            79.8  351182.0  392911.0
# 2         14.0        NaN         600             NaN       0.0       NaN
# 3        236.0        NaN       20000            71.1     100.0       NaN
# 4        135.0        NaN        2500             NaN       0.0       NaN
#
#                  LocalName                            GovernmentForm  \
# 0            Amerika Samoa                              US Territory
# 1                Australia       Constitutional Monarchy, Federation
# 2  Cocos (Keeling) Islands                    Territory of Australia
# 3         The Cook Islands  Nonmetropolitan Territory of New Zealand
# 4         Christmas Island                    Territory of Australia
#
#       HeadOfState  Capital Code2
# 0  George W. Bush     54.0    AS
# 1    Elisabeth II    135.0    AU
# 2    Elisabeth II   2317.0    CC
# 3    Elisabeth II    583.0    CK
# 4    Elisabeth II   1791.0    CX

# %% [markdown]
# ### Option 2: Use SQLAlchemy which is Recommended for Production

# %%
# !pip install SQLAlchemy
# Out:
# Collecting SQLAlchemy
#   Downloading sqlalchemy-2.0.41-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from SQLAlchemy)
#   Downloading greenlet-3.2.3-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in e:\anaconda3\envs\python_env\lib\site-packages (from SQLAlchemy) (4.14.0)
# Downloading sqlalchemy-2.0.41-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 840.2 kB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.4 MB/s eta 0:00:00
# Downloading greenlet-3.2.3-cp310-cp310-win_amd64.whl (296 kB)
# Installing collected packages: greenlet, SQLAlchemy
#
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    ---------------------------------------- 2/2 [SQLAlchemy]
#
# Successfully installed SQLAlchemy-2.0.41 greenlet-3.2.3

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# create a SQLAlchemy engine
engine = create_engine("mysql+mysqlconnector://root:@localhost/world")

# %%
df = pd.read_sql("SELECT * FROM country WHERE Continent='Oceania'", con=engine)
df.head()
# Out:
#   Code                     Name Continent                     Region  \
# 0  ASM           American Samoa   Oceania                  Polynesia
# 1  AUS                Australia   Oceania  Australia and New Zealand
# 2  CCK  Cocos (Keeling) Islands   Oceania  Australia and New Zealand
# 3  COK             Cook Islands   Oceania                  Polynesia
# 4  CXR         Christmas Island   Oceania  Australia and New Zealand
#
#    SurfaceArea  IndepYear  Population  LifeExpectancy       GNP    GNPOld  \
# 0        199.0        NaN       68000            75.1     334.0       NaN
# 1    7741220.0     1901.0    18886000            79.8  351182.0  392911.0
# 2         14.0        NaN         600             NaN       0.0       NaN
# 3        236.0        NaN       20000            71.1     100.0       NaN
# 4        135.0        NaN        2500             NaN       0.0       NaN
#
#                  LocalName                            GovernmentForm  \
# 0            Amerika Samoa                              US Territory
# 1                Australia       Constitutional Monarchy, Federation
# 2  Cocos (Keeling) Islands                    Territory of Australia
# 3         The Cook Islands  Nonmetropolitan Territory of New Zealand
# 4         Christmas Island                    Territory of Australia
#
#       HeadOfState  Capital Code2
# 0  George W. Bush     54.0    AS
# 1    Elisabeth II    135.0    AU
# 2    Elisabeth II   2317.0    CC
# 3    Elisabeth II    583.0    CK
# 4    Elisabeth II   1791.0    CX

# %% [markdown]
# #### What we have solved with this technique?
# 1. No Warnings
# 2. More Compatibility with pandas
# 3. Clean syntax for advanced queries and transactions
