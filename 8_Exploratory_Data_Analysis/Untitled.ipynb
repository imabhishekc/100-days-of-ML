# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_parquet("reading.parquet")

# %%
df.head()
# Out:
#   AGE_CATEGORY GENDER    MAJOR  MINUTES_READING  MINUTES_BREAK  FOCUS_LEVEL  \
# 0  young_adult   male  student               80             10            2
# 1  young_adult   male  student               80             10            2
# 2  young_adult   male  student               80             20            1
# 3  young_adult   male  student               48              4            3
# 4  young_adult   male  student               95             22            3
#
#    PAGES  CONTENT_LEVEL_ENUM           READING_GENRE SOUND_VOLUME  ...  \
# 0    8.0                   2  technical_&_vocational       silent  ...
# 1    8.0                   3  technical_&_vocational       silent  ...
# 2   14.0                   2  technical_&_vocational       silent  ...
# 3    3.0                   3  technical_&_vocational       silent  ...
# 4    7.0                   3  technical_&_vocational       silent  ...
#
#   LOCATION WEATHER          MOOD           HUNGER        AROUSAL  \
# ...

# %%
sns.countplot(x='MINUTES_READING', data=df, hue=df['PAGES'])
df['MINUTES_READING'].value_counts()
# Out:
# MINUTES_READING
# 60     7
# 99     5
# 80     3
# 110    3
# 91     3
#       ..
# 456    1
# 79     1
# 114    1
# 56     1
# 92     1
# Name: count, Length: 72, dtype: int64
